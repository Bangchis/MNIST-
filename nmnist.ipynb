# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten


# load data

mnist = tf.keras.datasets.mnist

# split test and train data
(X_train, y_train), (X_test, y_test) = mnist.load_data()


# Normalize data
X_train_normalized = X_train / 255.0
X_test_normalized = X_test / 255.0

# neural network

model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(units=128, activation="relu"),
    Dense(units=64, activation="relu"),
    Dense(units=10, activation="linear")
])

# complie model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(
                  from_logits=True),
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=5)
test_loss, test_acc = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6663 - loss: 4.5180
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8590 - loss: 0.5270
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9294 - loss: 0.2679
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9520 - loss: 0.1770
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9644 - loss: 0.1408
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.9585 - loss: 0.1545

# %%
loss_history = history.history.get('loss')
plt.figure(figsize=(10, 6))
plt.plot(loss_history, label='Test Loss', color='r')
plt.title('Test Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
